# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_colwidth', None)
pd.set_option("display.colheader_justify","left")

# %%
df_sample = pd.read_excel("SampleSentences.xlsx", header=None)
df_sample.style.set_properties(**{'text-align': 'left'})
# Out:
# <style type="text/css">
# #T_fd13f_row0_col0, #T_fd13f_row1_col0, #T_fd13f_row2_col0, #T_fd13f_row3_col0, #T_fd13f_row4_col0, #T_fd13f_row5_col0, #T_fd13f_row6_col0, #T_fd13f_row7_col0, #T_fd13f_row8_col0, #T_fd13f_row9_col0, #T_fd13f_row10_col0, #T_fd13f_row11_col0, #T_fd13f_row12_col0, #T_fd13f_row13_col0, #T_fd13f_row14_col0, #T_fd13f_row15_col0, #T_fd13f_row16_col0, #T_fd13f_row17_col0, #T_fd13f_row18_col0, #T_fd13f_row19_col0, #T_fd13f_row20_col0, #T_fd13f_row21_col0, #T_fd13f_row22_col0, #T_fd13f_row23_col0, #T_fd13f_row24_col0, #T_fd13f_row25_col0, #T_fd13f_row26_col0, #T_fd13f_row27_col0, #T_fd13f_row28_col0, #T_fd13f_row29_col0, #T_fd13f_row30_col0, #T_fd13f_row31_col0, #T_fd13f_row32_col0, #T_fd13f_row33_col0, #T_fd13f_row34_col0, #T_fd13f_row35_col0, #T_fd13f_row36_col0, #T_fd13f_row37_col0, #T_fd13f_row38_col0, #T_fd13f_row39_col0, #T_fd13f_row40_col0, #T_fd13f_row41_col0, #T_fd13f_row42_col0, #T_fd13f_row43_col0, #T_fd13f_row44_col0, #T_fd13f_row45_col0, #T_fd13f_row46_col0, #T_fd13f_row47_col0, #T_fd13f_row48_col0, #T_fd13f_row49_col0, #T_fd13f_row50_col0, #T_fd13f_row51_col0, #T_fd13f_row52_col0, #T_fd13f_row53_col0, #T_fd13f_row54_col0, #T_fd13f_row55_col0, #T_fd13f_row56_col0, #T_fd13f_row57_col0, #T_fd13f_row58_col0, #T_fd13f_row59_col0, #T_fd13f_row60_col0, #T_fd13f_row61_col0, #T_fd13f_row62_col0, #T_fd13f_row63_col0, #T_fd13f_row64_col0, #T_fd13f_row65_col0, #T_fd13f_row66_col0, #T_fd13f_row67_col0, #T_fd13f_row68_col0, #T_fd13f_row69_col0, #T_fd13f_row70_col0, #T_fd13f_row71_col0, #T_fd13f_row72_col0, #T_fd13f_row73_col0, #T_fd13f_row74_col0, #T_fd13f_row75_col0, #T_fd13f_row76_col0, #T_fd13f_row77_col0, #T_fd13f_row78_col0, #T_fd13f_row79_col0, #T_fd13f_row80_col0, #T_fd13f_row81_col0, #T_fd13f_row82_col0, #T_fd13f_row83_col0, #T_fd13f_row84_col0, #T_fd13f_row85_col0, #T_fd13f_row86_col0, #T_fd13f_row87_col0, #T_fd13f_row88_col0, #T_fd13f_row89_col0, #T_fd13f_row90_col0, #T_fd13f_row91_col0, #T_fd13f_row92_col0, #T_fd13f_row93_col0, #T_fd13f_row94_col0, #T_fd13f_row95_col0, #T_fd13f_row96_col0, #T_fd13f_row97_col0, #T_fd13f_row98_col0, #T_fd13f_row99_col0, #T_fd13f_row100_col0, #T_fd13f_row101_col0, #T_fd13f_row102_col0, #T_fd13f_row103_col0, #T_fd13f_row104_col0, #T_fd13f_row105_col0, #T_fd13f_row106_col0, #T_fd13f_row107_col0, #T_fd13f_row108_col0, #T_fd13f_row109_col0, #T_fd13f_row110_col0, #T_fd13f_row111_col0, #T_fd13f_row112_col0, #T_fd13f_row113_col0, #T_fd13f_row114_col0, #T_fd13f_row115_col0, #T_fd13f_row116_col0, #T_fd13f_row117_col0, #T_fd13f_row118_col0, #T_fd13f_row119_col0, #T_fd13f_row120_col0, #T_fd13f_row121_col0, #T_fd13f_row122_col0, #T_fd13f_row123_col0, #T_fd13f_row124_col0, #T_fd13f_row125_col0, #T_fd13f_row126_col0, #T_fd13f_row127_col0, #T_fd13f_row128_col0, #T_fd13f_row129_col0, #T_fd13f_row130_col0, #T_fd13f_row131_col0, #T_fd13f_row132_col0, #T_fd13f_row133_col0, #T_fd13f_row134_col0, #T_fd13f_row135_col0, #T_fd13f_row136_col0, #T_fd13f_row137_col0, #T_fd13f_row138_col0, #T_fd13f_row139_col0, #T_fd13f_row140_col0, #T_fd13f_row141_col0, #T_fd13f_row142_col0, #T_fd13f_row143_col0, #T_fd13f_row144_col0, #T_fd13f_row145_col0, #T_fd13f_row146_col0, #T_fd13f_row147_col0, #T_fd13f_row148_col0, #T_fd13f_row149_col0, #T_fd13f_row150_col0, #T_fd13f_row151_col0, #T_fd13f_row152_col0, #T_fd13f_row153_col0, #T_fd13f_row154_col0, #T_fd13f_row155_col0, #T_fd13f_row156_col0, #T_fd13f_row157_col0, #T_fd13f_row158_col0, #T_fd13f_row159_col0, #T_fd13f_row160_col0, #T_fd13f_row161_col0, #T_fd13f_row162_col0, #T_fd13f_row163_col0, #T_fd13f_row164_col0, #T_fd13f_row165_col0, #T_fd13f_row166_col0, #T_fd13f_row167_col0, #T_fd13f_row168_col0, #T_fd13f_row169_col0, #T_fd13f_row170_col0, #T_fd13f_row171_col0, #T_fd13f_row172_col0, #T_fd13f_row173_col0, #T_fd13f_row174_col0, #T_fd13f_row175_col0, #T_fd13f_row176_col0, #T_fd13f_row177_col0, #T_fd13f_row178_col0, #T_fd13f_row179_col0, #T_fd13f_row180_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_fd13f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd13f_level0_col0" class="col_heading level0 col0" >0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd13f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd13f_row0_col0" class="data row0 col0" > A small group of individuals, often military officers, plan and coordinate the coup in secret, determining their goals and strategy. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd13f_row1_col0" class="data row1 col0" > The identification of goals and objectives by the coup plotters, such as overthrowing the government or establishing a new government.</td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd13f_row2_col0" class="data row2 col0" > The recruitment of supporters by the coup plotters, often from the military or security forces, to participate in the coup.</td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd13f_row3_col0" class="data row3 col0" > The gathering of intelligence by the coup plotters about the government and its leaders, including their strengths and weaknesses, to help plan the coup. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd13f_row4_col0" class="data row4 col0" > The building of alliances by the coup plotters with other individuals and organizations, such as opposition leaders or civil society organizations, to help support the coup. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd13f_row5_col0" class="data row5 col0" > The development of a strategy by the coup plotters for carrying out the coup, including determining the timing and methods for disrupting normal government functions and seizing key institutions and infrastructure. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd13f_row6_col0" class="data row6 col0" > The coup plotters disrupt normal government functions, such as communications, transportation, and the ability of the government to respond to the coup. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd13f_row7_col0" class="data row7 col0" >The coup plotters seize key institutions, such as government buildings, communications centers, and military bases, to disrupt normal government functions. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd13f_row8_col0" class="data row8 col0" >The coup plotters cut off communication, such as telephone and internet networks, to prevent the government from communicating with the public and with other government institutions. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd13f_row9_col0" class="data row9 col0" >The coup plotters disrupt transportation, such as closing airports and highways, to prevent the government from moving troops and supplies. </td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fd13f_row10_col0" class="data row10 col0" >The coup plotters confine government leaders, such as the president and members of the cabinet, to prevent them from leading the government and communicating with the public.</td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fd13f_row11_col0" class="data row11 col0" >The coup plotters disrupt the military command structure, such as by arresting key military leaders or by disrupting communication between military units, to prevent the military from counterattacking the coup.</td>
#     </tr>
#     <tr>
#       <th id="T_fd13f_l

# %%
import spacy
nlp = spacy.load('en_core_web_md')

# %%
# Write a function to display basic entity info:
def show_ents(doc):
    if doc.ents:
        for ent in doc.ents:
            print(ent.text+' - '+ent.label_+' - '+str(spacy.explain(ent.label_)))
    else:
        print('No named entities found.')

# %%
doc = nlp(df_sample.to_string())
# doc = nlp(u'IBM is located in Kolkata in India')

show_ents(doc)
# Out:
# 1 - CARDINAL - Numerals that do not fall under another type
# 2 - CARDINAL - Numerals that do not fall under another type
# 3 - CARDINAL - Numerals that do not fall under another type
# 4 - CARDINAL - Numerals that do not fall under another type
# 5 - CARDINAL - Numerals that do not fall under another type
# 6 - CARDINAL - Numerals that do not fall under another type
# 7 - CARDINAL - Numerals that do not fall under another type
# 8 - CARDINAL - Numerals that do not fall under another type
# 9 - CARDINAL - Numerals that do not fall under another type
# 10 - CARDINAL - Numerals that do not fall under another type
# 11 - CARDINAL - Numerals that do not fall under another type
# 12                                                                                                                                                     - QUANTITY - Measurements, as of weight or distance
# 13 - CARDINAL - Numerals that do not fall under another type
# 14 - CARDINAL - Numerals that do not fall under another type
# 15 - CARDINAL - Numerals that do not fall under another type
# 16 - CARDINAL - Numerals that do not fall under another type
# 17 - CARDINAL - Numerals that do not fall under another type
# 18 - CARDINAL - Numerals that do not fall under another type
# 19                                                                                              - CARDINAL - Numerals that do not fall under another type
# 20 - CARDINAL - Numerals that do not fall under another type
# 21 - CARDINAL - Numerals that do not fall under another type
# 22 - CARDINAL - Numerals that do not fall under another type
# 23 - CARDINAL - Numerals that do not fall under another type
# 24 - CARDINAL - Numerals that do not fall under another type
# 25 - CARDINAL - Numerals that do not fall under another type
# 26 - CARDINAL - Numerals that do not fall under another type
# 27 - CARDINAL - Numerals that do not fall under another type
# 28 - CARDINAL - Numerals that do not fall under another type
# 29 - CARDINAL - Numerals that do not fall under another type
# 30 - CARDINAL - Numerals that do not fall under another type
# 31 - CARDINAL - Numerals that do not fall under another type
# 32 - CARDINAL - Numerals that do not fall under another type
# 33 - CARDINAL - Numerals that do not fall under another type
# 34                                                                                                                                                                                                     - CARDINAL - Numerals that do not fall under another type
# 35 - CARDINAL - Numerals that do not fall under another type
# 36                                                                                                                                                               - CARDINAL - Numerals that do not fall under another type
# 37 - CARDINAL - Numerals that do not fall under another type
# 38 - CARDINAL - Numerals that do not fall under another type
# 39 - CARDINAL - Numerals that do not fall under another type
# 40 - CARDINAL - Numerals that do not fall under another type
# 41 - CARDINAL - Numerals that do not fall under another type
# 42 - CARDINAL - Numerals that do not fall under another type
# 43 - CARDINAL - Numerals that do not fall under another type
# 44 - CARDINAL - Numerals that do not fall under another type
# 45 - CARDINAL - Numerals that do not fall under another type
# 46 - CARDINAL - Numerals that do not fall under another type
# 47 - CARDINAL - Numerals that do not fall under another type
# 48 - CARDINAL - Numerals that do not fall under another type
# 49 - CARDINAL - Numerals that do not fall under another type
# 50 - CARDINAL - Numerals that do not fall under another type
# 51 - CARDINAL - Numerals that do not fall under another type
# 52 - CARDINAL - Numerals that do not fall under another type
# 53 - CARDINAL - Numerals that do not fall under another type
# 54 - CARDINAL - Numerals that do not fall under another type
# 55 - CARDINAL - Numerals that do not fall under another type
# 56 - CARDINAL - Numerals that do not fall under another type
# 57 - CARDINAL - Numerals that do not fall under another type
# 58 - CARDINAL - Numerals that do not fall under another type
# 59 - CARDINAL - Numerals that do not fall under another type
# 60 - CARDINAL - Numerals that do not fall under another type
# 61 - CARDINAL - Numerals that do not fall under another type
# 62 - CARDINAL - Numerals that do not fall under another type
# 63 - CARDINAL - Numerals that do not fall under another type
# 64 - CARDINAL - Numerals that do not fall under another type
# 65 - CARDINAL - Numerals that do not fall under another type
# 66 - CARDINAL - Numerals that do not fall under another type
# 67 - CARDINAL - Numerals that do not fall under another type
# 68 - CARDINAL - Numerals that do not fall under another type
# one - CARDINAL - Numerals that do not fall under another type
# 69 - CARDINAL - Numerals that do not fall under another type
# 70 - CARDINAL - Numerals that do not fall under another type
# 71 - CARDINAL - Numerals that do not fall under another type
# 72 - CARDINAL - Numerals that do not fall under another type
# 73 - CARDINAL - Numerals that do not fall under another type
# 74 - CARDINAL - Numerals that do not fall under another type
# 75 - CARDINAL - Numerals that do not fall under another type
# 76 - CARDINAL - Numerals that do not fall under another type
# 77 - CARDINAL - Numerals that do not fall under another type
# 78 - CARDINAL - Numerals that do not fall under another type
# 79 - CARDINAL - Numerals that do not fall under another type
# 81 - CARDINAL - Numerals that do not fall under another type
# 82 - CARDINAL - Numerals that do not fall under another type
# 83 - CARDINAL - Numerals that do not fall under another type
# 84 - CARDINAL - Numerals that do not fall under another type
# 85 - CARDINAL - Numerals that do not fall under another type
# 86 - CARDINAL - Numerals that do not fall under another type
# 87 - CARDINAL - Numerals that do not fall under another type
# 88 - CARDINAL - Numerals that do not fall under another type
# 89 - CARDINAL - Numerals that do not fall under another type
# 90 - CARDINAL - Numerals that do not fall under another type
# 91 - CARDINAL - Numerals that do not fall under another type
# 93                                               - CARDINAL - Numerals that do not fall under another type
# 94 - CARDINAL - Numerals that do not fall under another type
# first - ORDINAL - "first", "second", etc.
# 95 - CARDINAL - Numerals that do not fall under another type
# 96 - CARDINAL - Numerals that do not fall under another type
# 97 - CARDINAL - Numerals that do not fall under another type
# 98 - CARDINAL - Numerals that do not fall under another type
# 99                                                                                           - CARDINAL - Numerals that do not fall under another type
# 100 - CARDINAL - Numerals that do not fall under another type
# 101 - CARDINAL - Numerals that do not fall under another type
# 102 - CARDINAL - Numerals that do not fall under another type
# 103 - CARDINAL - Numerals that do not fall under another type
# 104 - CARDINAL - Numerals that do not fall under another type
# 105 - CARDINAL - Numerals that do not fall under another type
# 106 - CARDINAL - Numerals that do not fall under another type
# 107 - CARDINAL - Numerals that do not fall under another type
# 108 - CARDINAL - Numerals that do not fall under another type
# 109 - CARDINAL - Numerals that do not fall under another type
# 110 - CARDINAL - Numerals that do not fall under another type
# 111 - CARDINAL - Numerals that do not fall under another type
# 112 - CARDINAL - Numerals that do not fall under another type
# 113 - CARDINAL - Numerals that do not fall under another type
# 115 - CARDINAL - Numerals that do not fall under another type
# 116 - CARDINAL - Numerals that do not fall under another type
# 117 - CARDINAL - Numerals that do not fall under another type
# one - CARDINAL - Numerals that do not fall under another type
# 118 - CARDINAL - Numerals that do not fall under another type
# 119 - CARDINAL - Numerals that do not fall under another type
# 120 - CARDINAL - Numerals that do not fall under another type
# 121 - CARDINAL - Numerals that do not fall under another type
# 122 - CARDINAL - Numerals that do not fall under another type
# 123 - CARDINAL - Numerals that do not fall under another type
# 124 - CARDINAL - Numerals that do not fall under another type
# 125 - CARDINAL - Numerals that do not fall under another type
# 126                                                                                              - CARDINAL - Numerals that do not fall under another type
# 127 - CARDINAL - Numerals that do not fall under another type
# 128 - CARDINAL - Numerals that do not fall under another type
# 129 - CARDINAL - Numerals that do not fall under another type
# 130                                                                                                                                                                                              - QUANTITY - Measurements, as of weight or distance
# 131 - CARDINAL - Numerals that do not fall under another type
# 132 - CARDINAL - Numerals that do not fall under another type
# 133 - CARDINAL - Numerals that do not fall under another type
# 134                                                                                                                                                                                                                - QUANTITY - Measurements, as of weight or distance
# 135 - CARDINAL - Numerals that do not fall under another type
# 136 - CARDINAL - Numerals that do not fall under another type
# 137 - CARDINAL - Numerals that do not fall under another type
# 138                                                                                                                                                                         - QUANTITY - Measurements, as of weight or distance
# 139 - CARDINAL - Numerals that do not fall under another type
# 140 - CARDINAL - Numerals that do not fall under another type
# 141 - CARDINAL - Numerals that do not fall under another type
# 142 - CARDINAL - Numerals that do not fall under another type
# 143 - CARDINAL - Numerals that do not fall under another type
# 144 - CARDINAL - Numerals that do not fall under another type
# 145 - CARDINAL - Numerals that do not fall under another type
# 146 - CARDINAL - Numerals that do not fall under another type
# 147 - CARDINAL - Numerals that do not fall under another type
# 148 - CARDINAL - Numerals that do not fall under another type
# 149 - CARDINAL - Numerals that do not fall under another type
# 150 - CARDINAL - Numerals that do not fall under another type
# 151 - CARDINAL - Numerals that do not fall under another type
# 152 - CARDINAL - Numerals that do not fall under another type
# 153 - CARDINAL - Numerals that do not fall under another type
# 154 - CARDINAL - Numerals that do not fall under another type
# 155 - CARDINAL - Numerals that do not fall under another type
# 156 - CARDINAL - Numerals that do not fall under another type
# 157 - CARDINAL - Numerals that do not fall under another type
# 158 - CARDINAL - Numerals that do not fall under another type
# 159 - CARDINAL - Numerals that do not fall under another type
# 160 - CARDINAL - Numerals that do not fall under another type
# 161 - CARDINAL - Numerals that do not fall under another type
# 162 - CARDINAL - Numerals that do not fall under another type
# 163 - CARDINAL - Numerals that do not fall under another type
# 164 - CARDINAL - Numerals that do not fall under another type
# 165 - CARDINAL - Numerals that do not fall under another type
# 167 - CARDINAL - Numerals that do not fall under another type
# 168 - CARDINAL - Numerals that do not fall under another type
# 170 - CARDINAL - Numerals that do not fall under another type
# 171 - CARDINAL - Numerals that do not fall under another type
# 172 - CARDINAL - Numerals that do not fall under another type
# 173 - CARDINAL - Numerals that do not fall under another type
# 174 - CARDINAL - Numerals that do not fall under another type
# 175 - CARDINAL - Numerals that do not fall under another type
# 176 - CARDINAL - Numerals that do not fall under another type
# 177 - CARDINAL - Numerals that do not fall under another type
# 178 - CARDINAL - Numerals that do not fall under another type
# 179                                                                                                  - QUANTITY - Measurements, as of weight or distance
# 180 - CARDINAL - Numerals that do not fall under another type

# %%
# from spacy import displacy

# displacy.render(doc, style='ent', jupyter='true')

# %% [markdown]
# <h4>Spacy Entity Linker</h4>
#
# https://pypi.org/project/spacy-entity-linker/

# %%
# add pipeline 
import spacy_entity_linker as entityLinker
nlp.add_pipe("entityLinker", last=True)

# %%
doc2 = nlp(df_sample.to_string())
all_linked_entities = doc2._.linkedEntities
all_linked_entities.pretty_print()
# Out:
# <EntityElement: https://www.wikidata.org/wiki/Q83478 group                     algebraic set with an invertible, associative internal operation admitting a neutral element>
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q189290 military officer          member of an armed force or uniformed service who holds a position of authority>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q4503831 goal                      desired result or outcome                         >
# <EntityElement: https://www.wikidata.org/wiki/Q185451 strategy                  high-level plan to achieve objectives in uncertain conditions>
# <EntityElement: https://www.wikidata.org/wiki/Q2991771 gathering                 collecting wild food plants                       >
# <EntityElement: https://www.wikidata.org/wiki/Q83500 intelligence              mental faculty                                    >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q32518 ellipsis                  series of dots that indicate omission             >
# <EntityElement: https://www.wikidata.org/wiki/Q1989404 strength                  concept in formal logic                           >
# <EntityElement: https://www.wikidata.org/wiki/Q633403 asthenia                  symptom                                           >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q385378 construction              process that consists of the building or assembling of a building or infrastructure>
# <EntityElement: https://www.wikidata.org/wiki/Q131569 treaty                    express agreement under international law entered into by actors in international law>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q43229 organization              social entity (not necessarily commercial) uniting people into a structured group managing shared me>
# <EntityElement: https://www.wikidata.org/wiki/Q32518 ellipsis                  series of dots that indicate omission             >
# <EntityElement: https://www.wikidata.org/wiki/Q8425 society                   group of people related to each other through persistent relations>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q11348 function                  mathematical binary relation between two sets, which is right-unique, but not necessarily left-total>
# <EntityElement: https://www.wikidata.org/wiki/Q11024 communication             act of conveying intended meanings from one entity or group to another through the use of mutually u>
# <EntityElement: https://www.wikidata.org/wiki/Q7590 transport                 human-directed movement of things or people between locations>
# <EntityElement: https://www.wikidata.org/wiki/Q1347367 capability                ability; competence to do a certain kind of work at a certain level>
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q11024 communication             act of conveying intended meanings from one entity or group to another through the use of mutually u>
# <EntityElement: https://www.wikidata.org/wiki/Q141488 graph                     mathematical structure; representation of a set of objects where some pairs of the objects are conne>
# <EntityElement: https://www.wikidata.org/wiki/Q11035 telephone                 telecommunications device                         >
# <EntityElement: https://www.wikidata.org/wiki/Q75 Internet                  global system of connected computer networks      >
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q211198 audience                  group of people who participate in a show or encounter a work of art>
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q2285706 head of government        chief officer of the executive branch of a government>
# <EntityElement: https://www.wikidata.org/wiki/Q1255921 president                 non-political leader of an organization, company, community, club, trade union, university or other >
# <EntityElement: https://www.wikidata.org/wiki/Q379825 element                   any one of the distinct objects that make up a set in set theory>
# <EntityElement: https://www.wikidata.org/wiki/Q640506 cabinet                   group of high ranking officials, usually representing the executive branch of government>
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q211198 audience                  group of people who participate in a show or encounter a work of art>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q178706 institution               structure or mechanism of social order and cooperation governing the behaviour of a set of individua>
# <EntityElement: https://www.wikidata.org/wiki/Q121359 infrastructure            fundamental facilities and systems serving a country, city, or other areas>
# <EntityElement: https://www.wikidata.org/wiki/Q1540447 Government Buildings      architectural structure located in Dublin, Ireland>
# <EntityElement: https://www.wikidata.org/wiki/Q11024 communication             act of conveying intended meanings from one entity or group to another through the use of mutually u>
# <EntityElement: https://www.wikidata.org/wiki/Q4866727 bases                     skirts worn with armor                            >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q1162163 director                  person who leads a particular area of a company or organisation>
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q32518 ellipsis                  series of dots that indicate omission             >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q11175 circumflex                diacritic in Latin, Greek and Cyrillic scripts    >
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q568759 Public Announcement       band                                              >
# <EntityElement: https://www.wikidata.org/wiki/Q11175 circumflex                diacritic in Latin, Greek and Cyrillic scripts    >
# <EntityElement: https://www.wikidata.org/wiki/Q1740954 tunica media              middle layer of blood vessel                      >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q192852 political opposition      political force against majority                  >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q11402 force                     influence that causes an object to change motion  >
# <EntityElement: https://www.wikidata.org/wiki/Q273120 protest                   expression of objection                           >
# <EntityElement: https://www.wikidata.org/wiki/Q32518 ellipsis                  series of dots that indicate omission             >
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q11175 circumflex                diacritic in Latin, Greek and Cyrillic scripts    >
# <EntityElement: https://www.wikidata.org/wiki/Q7188 government                system or group of people governing an organized community, often a state>
# <EntityElement: https://www.wikidata.org/wiki/Q3336843 country within the United Kingdom one of four constituent parts of the United Kingdom:  England, Wales, Scotland and Northern Ireland>
# <EntityElement: https://www.wikidata.org/wiki/Q3497146 Late Qing Reforms         series of political, economical, military, cultural and educational reforms that were implemented in>
# <EntityElement: https://www.wikidata.org/wiki/Q178706 institution               structure or mechanism of social order and cooperation governing the behaviour of a set of individua>
# <EntityElement: https://www.wikidata.org/wiki/Q207982 political legitimacy      right and acceptance of an authority              >
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q11402 force                     influence that causes an object to change motion  >
# <EntityElement: https://www.wikidata.org/wiki/Q45382 coup d'état               sudden deposition of a government; illegal and overt seizure of a state by the military or other eli>
# <EntityElement: https://www.wikidata.org/wiki/Q41263 budget                    balance sheet or statement of estimated receipts and expenditures>
# <EntityElement: https://www.wikidata.org/wiki/Q25342 power                     rate at which energy is transferred, used, or transformed>
# <EntityElement: https://www.wikidata.org/wiki/Q188613 confirmation              rite where baptism is confirmed in several Christian denominations>
# <EntityElement: https://www.wikidata.org/wiki/Q483242 laboratory                facility that provides controlled conditions in which scientific or technological research, experime>
# <EntityElement: https://www.wikidata.org/wiki/Q190686 subroutine                sequence of computer instructions that can be called from other points in a program>
# <EntityElement: https://www.wikidata.org/wiki/Q215408 Presence                  1976 studio album by Led Zeppelin                 >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q206637 computer cluster          group of computers                                >
# <EntityElement: https://www.wikidata.org/wiki/Q3052382 fonds                     aggregation of documents that originate from the same source>
# <EntityElement: https://www.wikidata.org/wiki/Q7754 mathematical analysis                                                       >
# <EntityElement: https://www.wikidata.org/wiki/Q42848 data                      facts represented for handling                    >
# <EntityElement: https://www.wikidata.org/wiki/Q8188561 letter case               property of a letter in bicameral alphabets (most notably the Latin one); piece of information wheth>
# <EntityElement: https://www.wikidata.org/wiki/Q2249676 environment               surrounding of an organism or population          >
# <EntityElement: https://www.wikidata.org/wiki/Q5850078 etiology                  reason or origination of some disease             >
# <EntityElement: https://www.wikidata.org/wiki/Q128751 source code               collection of computer instructions written using some human-readable computer language>
# <EntityElement: https://www.wikidata.org/wiki/Q44512 epidemic                  rapid spread of infectious disease to a large number of people in a given population within a short >
# <EntityElement: https://www.wikidata.org/wiki/Q1475848 risk factor               variable associated with an increased risk of disease or infection>
# <EntityElement: https://www.wikidata.org/wiki/Q12684 fashion                   popular style or practice in clothing, personal adornment, or decorative arts>
# <EntityElement: https://www.wikidata.org/wiki/Q6497460 transmission              machine in a power transmission system for controlled application of the power;gearbox,uses gears/ge>
# <EntityElement: https://www.wikidata.org/wiki/Q177719 diagnostic procedure      process to determine or identify a disease or disorder>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q169872 symptom                   departure from normal function or feeling which is noticed by a patient, reflecting the presence of >
# <EntityElement: https://www.wikidata.org/wiki/Q181600 patient                   person who takes a medical treatment or is subject of a case study>
# <EntityElement: https://www.wikidata.org/wiki/Q1211272 signage                   design or use of signs and symbols to communicate a message to a specific group, usually for the pur>
# <EntityElement: https://www.wikidata.org/wiki/Q835153 physical examination      process by which a medical professional investigates the body of a patient for signs of disease>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q483242 laboratory                facility that provides controlled conditions in which scientific or technological research, experime>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q7901733 Use                                                                         >
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q886837 blood test                laboratory analysis using a blood sample          >
# <EntityElement: https://www.wikidata.org/wiki/Q11042 culture                   society's way of life within anthropology         >
# <EntityElement: https://www.wikidata.org/wiki/Q21162272 means                     means by which an item performs a function        >
# <EntityElement: https://www.wikidata.org/wiki/Q21004260 inquiry                   process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# <EntityElement: https://www.wikidata.org/wiki/Q2083958 pattern                   discernible regularity in the world or in a manmade design>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q1475848 risk factor               variable associated with an increased risk of disease or infection>
# <EntityElement: https://www.wikidata.org/wiki/Q7901733 Use                                                                         >
# <EntityElement: https://www.wikidata.org/wiki/Q5382703 epidemiological method                                                      >
# <EntityElement: https://www.wikidata.org/wiki/Q39546 tool                      physical item that can be used to achieve a goal  >
# <EntityElement: https://www.wikidata.org/wiki/Q11175 circumflex                diacritic in Latin, Greek and Cyrillic scripts    >
# <EntityElement: https://www.wikidata.org/wiki/Q4008388 exposure assessment                                                         >
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q466845 tracking                  separating students by ability                    >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q104493 risk                      potential for uncontrolled loss                   >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q7901733 Use                                                                         >
# <EntityElement: https://www.wikidata.org/wiki/Q190686 subroutine                sequence of computer instructions that can be called from other points in a program>
# <EntityElement: https://www.wikidata.org/wiki/Q39546 tool                      physical item that can be used to achieve a goal  >
# <EntityElement: https://www.wikidata.org/wiki/Q3052382 fonds                     aggregation of documents that originate from the same source>
# <EntityElement: https://www.wikidata.org/wiki/Q29017603 control                   influence or authority over something; process of directing the operation of a device, system, or pr>
# <EntityElement: https://www.wikidata.org/wiki/Q42848 data                      facts represented for handling                    >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q42848 data                      facts represented for handling                    >
# <EntityElement: https://www.wikidata.org/wiki/Q7754 mathematical analysis                                                       >
# <EntityElement: https://www.wikidata.org/wiki/Q42848 data                      facts represented for handling                    >
# <EntityElement: https://www.wikidata.org/wiki/Q1331926 decision making           Cognitive process resulting in choosing a course of action>
# <EntityElement: https://www.wikidata.org/wiki/Q1421432 monitoring                observation of a disease, condition or one or several medical parameters over time>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q61788060 human activity            activity initiated by a human                     >
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q272035 accuracy and precision    Closeness to true value or to each other          >
# <EntityElement: https://www.wikidata.org/wiki/Q177719 diagnostic procedure      process to determine or identify a disease or disorder>
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q11500 area                      quantity that expresses the extent of a two-dimensional surface or shape, or planar lamina, in the p>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q31207 health care               prevention of disease and promotion of wellbeing  >
# <EntityElement: https://www.wikidata.org/wiki/Q179661 treatment                 medical treatment                                 >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q245962 implementation            realization of an application, or execution of a plan, idea, model, design, specification, standard,>
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q1472481 spread                    food that is spread, generally with a knife, onto food products such as bread and crackers>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q192995 vaccination               administration of a vaccine to protect against disease>
# <EntityElement: https://www.wikidata.org/wiki/Q23797 contact lens              lens worn directly on the eye                     >
# <EntityElement: https://www.wikidata.org/wiki/Q179661 treatment                 medical treatment                                 >
# <EntityElement: https://www.wikidata.org/wiki/Q8188561 letter case               property of a letter in bicameral alphabets (most notably the Latin one); piece of information wheth>
# <EntityElement: https://www.wikidata.org/wiki/Q23009442 removal                   dissociation of the original object with its old part; moving an object on distance of disconnect; p>
# <EntityElement: https://www.wikidata.org/wiki/Q128751 source code               collection of computer instructions written using some human-readable computer language>
# <EntityElement: https://www.wikidata.org/wiki/Q166231 infection                 invasion of a host by disease-causing organisms   >
# <EntityElement: https://www.wikidata.org/wiki/Q182899 quarantine                epidemiological intervention to prevent disease transmission>
# <EntityElement: https://www.wikidata.org/wiki/Q275473 solitude                  state of seclusion or isolation of a person       >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q23797 contact lens              lens worn directly on the eye                     >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q1472481 spread                    food that is spread, generally with a knife, onto food products such as bread and crackers>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q31207 health care               prevention of disease and promotion of wellbeing  >
# <EntityElement: https://www.wikidata.org/wiki/Q179661 treatment                 medical treatment                                 >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q7901733 Use                                                                         >
# <EntityElement: https://www.wikidata.org/wiki/Q12140 medication                substance used to diagnose, cure, treat, or prevent disease>
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q3658527 Care                      band                                              >
# <EntityElement: https://www.wikidata.org/wiki/Q1421432 monitoring                observation of a disease, condition or one or several medical parameters over time>
# <EntityElement: https://www.wikidata.org/wiki/Q11030 journalism                investigation and reporting of events, issues and trends to a broad audience>
# <EntityElement: https://www.wikidata.org/wiki/Q8188561 letter case               property of a letter in bicameral alphabets (most notably the Latin one); piece of information wheth>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q44512 epidemic                  rapid spread of infectious disease to a large number of people in a given population within a short >
# <EntityElement: https://www.wikidata.org/wiki/Q1296024 effectiveness             capability of producing the desired result        >
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q483242 laboratory                facility that provides controlled conditions in which scientific or technological research, experime>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q42848 data                      facts represented for handling                    >
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q11030 journalism                investigation and reporting of events, issues and trends to a broad audience>
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q11000047 health system             system that consists of all organizations, people and actions whose primary intent is to promote, re>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q121359 infrastructure            fundamental facilities and systems serving a country, city, or other areas>
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q25206207 Equipment                 fashion label currently based in Los Angeles, California.>
# <EntityElement: https://www.wikidata.org/wiki/Q542869 supply                    in economics, the amount of a good that sellers are willing to provide in the market>
# <EntityElement: https://www.wikidata.org/wiki/Q918385 training                  acquisition of knowledge, skills, and competencies as a result of teaching>
# <EntityElement: https://www.wikidata.org/wiki/Q31207 health care               prevention of disease and promotion of wellbeing  >
# <EntityElement: https://www.wikidata.org/wiki/Q245962 implementation            realization of an application, or execution of a plan, idea, model, design, specification, standard,>
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q104493 risk                      potential for uncontrolled loss                   >
# <EntityElement: https://www.wikidata.org/wiki/Q44512 epidemic                  rapid spread of infectious disease to a large number of people in a given population within a short >
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q3473226 Hygiene                   unincorporated community in Colorado              >
# <EntityElement: https://www.wikidata.org/wiki/Q949149 sanitation                public health conditions related to clean drinking water and adequate disposal of human excreta and >
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q166231 infection                 invasion of a host by disease-causing organisms   >
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q334600 practice                  act of rehearsing a behavior repeatedly; sessions scheduled for the purpose of rehearsing and perfor>
# <EntityElement: https://www.wikidata.org/wiki/Q245962 implementation            realization of an application, or execution of a plan, idea, model, design, specification, standard,>
# <EntityElement: https://www.wikidata.org/wiki/Q60894 health education          education for awareness of and influence on the attitude of health>
# <EntityElement: https://www.wikidata.org/wiki/Q40056 computer program          sequence of instructions written in programming language to perform a specified task with a computer>
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q9332 behavior                  way that one acts in different situations         >
# <EntityElement: https://www.wikidata.org/wiki/Q334600 practice                  act of rehearsing a behavior repeatedly; sessions scheduled for the purpose of rehearsing and perfor>
# <EntityElement: https://www.wikidata.org/wiki/Q353163 promotion                 specific effort to promote a product or service   >
# <EntityElement: https://www.wikidata.org/wiki/Q2249676 environment               surrounding of an organism or population          >
# <EntityElement: https://www.wikidata.org/wiki/Q353163 promotion                 specific effort to promote a product or service   >
# <EntityElement: https://www.wikidata.org/wiki/Q1145523 collaboration             working together                                  >
# <EntityElement: https://www.wikidata.org/wiki/Q459221 sharing                   joint use of a resource or space                  >
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q830382 best practice             method that has shown results superior to those achieved with other means>
# <EntityElement: https://www.wikidata.org/wiki/Q1395034 new product development   complete process of bringing a new product to market>
# <EntityElement: https://www.wikidata.org/wiki/Q1371819 plan                      outline of a strategy for achievement of an objective>
# <EntityElement: https://www.wikidata.org/wiki/Q3716064 stiffening                method of increasing rigidity and structural integrity of materials or objects>
# <EntityElement: https://www.wikidata.org/wiki/Q5188114 Cross-border cooperation                                                    >
# <EntityElement: https://www.wikidata.org/wiki/Q1421432 monitoring                observation of a disease, condition or one or several medical parameters over time>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q1296024 effectiveness             capability of producing the desired result        >
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q4115667 impact                    high force or shock applied over a short time period when two or more bodies collide>
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q217690 incidence                 measure of the probability of occurrence of a given medical condition in a population within a speci>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q11500 area                      quantity that expresses the extent of a two-dimensional surface or shape, or planar lamina, in the p>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q1121708 failure                   state or condition of not meeting a desirable or intended objective>
# <EntityElement: https://www.wikidata.org/wiki/Q584049 ventilation               intentional introduction of outside air into a space>
# <EntityElement: https://www.wikidata.org/wiki/Q385378 construction              process that consists of the building or assembling of a building or infrastructure>
# <EntityElement: https://www.wikidata.org/wiki/Q178512 public transport          shared transportation service for use by the general public>
# <EntityElement: https://www.wikidata.org/wiki/Q4169 outer space               void between celestial bodies                     >
# <EntityElement: https://www.wikidata.org/wiki/Q2637489 air                       one of the four classical elements; universal power or pure substance>
# <EntityElement: https://www.wikidata.org/wiki/Q60528603 contamination             presence of an unwanted constituent, harmful substance or impurity in a material, physical body, or >
# <EntityElement: https://www.wikidata.org/wiki/Q170065 pathogen                  biological entity that causes disease in its host >
# <EntityElement: https://www.wikidata.org/wiki/Q24238946 liberation                act of liberating or state of being liberated     >
# <EntityElement: https://www.wikidata.org/wiki/Q2637489 air                       one of the four classical elements; universal power or pure substance>
# <EntityElement: https://www.wikidata.org/wiki/Q2249676 environment               surrounding of an organism or population          >
# <EntityElement: https://www.wikidata.org/wiki/Q10290214 event                     in statistics and probability theory, set of outcomes to which a probability is assigned>
# <EntityElement: https://www.wikidata.org/wiki/Q169950 wildfire                  uncontrolled fire in an area of combustible vegetation that occurs in the countryside or a wildernes>
# <EntityElement: https://www.wikidata.org/wiki/Q182878 dust storm                meteorological phenomenon common in arid and semi-arid regions>
# <EntityElement: https://www.wikidata.org/wiki/Q7692360 volcanic eruption         eruption of lava or tephra from a volcanic vent   >
# <EntityElement: https://www.wikidata.org/wiki/Q188613 confirmation              rite where baptism is confirmed in several Christian denominations>
# <EntityElement: https://www.wikidata.org/wiki/Q5850078 etiology                  reason or origination of some disease             >
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q483242 laboratory                facility that provides controlled conditions in which scientific or technological research, experime>
# <EntityElement: https://www.wikidata.org/wiki/Q190686 subroutine                sequence of computer instructions that can be called from other points in a program>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q104493 risk                      potential for uncontrolled loss                   >
# <EntityElement: https://www.wikidata.org/wiki/Q2637489 air                       one of the four classical elements; universal power or pure substance>
# <EntityElement: https://www.wikidata.org/wiki/Q1202245 potential                 currently unrealized ability                      >
# <EntityElement: https://www.wikidata.org/wiki/Q1472481 spread                    food that is spread, generally with a knife, onto food products such as bread and crackers>
# <EntityElement: https://www.wikidata.org/wiki/Q17125150 severity of illness index levels within a diagnostic group which are established by measurement criteria applied to the seriou>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q2625603 population                ensemble of individuals of a species in an area, or their number>
# <EntityElement: https://www.wikidata.org/wiki/Q104493 risk                      potential for uncontrolled loss                   >
# <EntityElement: https://www.wikidata.org/wiki/Q245962 implementation            realization of an application, or execution of a plan, idea, model, design, specification, standard,>
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q1472481 spread                    food that is spread, generally with a knife, onto food products such as bread and crackers>
# <EntityElement: https://www.wikidata.org/wiki/Q12136 disease                   abnormal condition negatively affecting organisms >
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q185957 quality                   non-inferiority or superiority of something; a perceptual, conditional, and somewhat subjective attr>
# <EntityElement: https://www.wikidata.org/wiki/Q245962 implementation            realization of an application, or execution of a plan, idea, model, design, specification, standard,>
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q8434 education                 learning in which knowledge and skills are transferred through teaching>
# <EntityElement: https://www.wikidata.org/wiki/Q211198 audience                  group of people who participate in a show or encounter a work of art>
# <EntityElement: https://www.wikidata.org/wiki/Q11024 communication             act of conveying intended meanings from one entity or group to another through the use of mutually u>
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q44512 epidemic                  rapid spread of infectious disease to a large number of people in a given population within a short >
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q211198 audience                  group of people who participate in a show or encounter a work of art>
# <EntityElement: https://www.wikidata.org/wiki/Q840576 dissemination                                                               >
# <EntityElement: https://www.wikidata.org/wiki/Q12147 health                    level of functional or metabolic efficiency of a living being>
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q128751 source code               collection of computer instructions written using some human-readable computer language>
# <EntityElement: https://www.wikidata.org/wiki/Q2637489 air                       one of the four classical elements; universal power or pure substance>
# <EntityElement: https://www.wikidata.org/wiki/Q840576 dissemination                                                               >
# <EntityElement: https://www.wikidata.org/wiki/Q3308979 advice                    official notice, opinion, counsel or recommendation that is optional or at the receiver's discretion>
# <EntityElement: https://www.wikidata.org/wiki/Q185957 quality                   non-inferiority or superiority of something; a perceptual, conditional, and somewhat subjective attr>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q1296024 effectiveness             capability of producing the desired result        >
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q2493413 identification            psychological process whereby the subject assimilates an aspect, property, or attribute of the other>
# <EntityElement: https://www.wikidata.org/wiki/Q11500 area                      quantity that expresses the extent of a two-dimensional surface or shape, or planar lamina, in the p>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q272035 accuracy and precision    Closeness to true value or to each other          >
# <EntityElement: https://www.wikidata.org/wiki/Q192276 measure                   mathematical function which associates a comparable numeric value to some subsets of a given set>
# <EntityElement: https://www.wikidata.org/wiki/Q27318 test                      procedure for measuring a subject's ability       >
# <EntityElement: https://www.wikidata.org/wiki/Q104493 risk                      potential for uncontrolled loss                   >
# <EntityElement: https://www.wikidata.org/wiki/Q2637489 air                       one of the four classical elements; universal power or pure substance>
# <EntityElement: https://www.wikidata.org/wiki/Q15713092 Food                      2014 Kelis album                                  >
# <EntityElement: https://www.wikidata.org/wiki/Q10876 bacteria                  domain of prokaryotes                             >
# ...
# <EntityElement: https://www.wikidata.org/wiki/Q1088842 detonator                 system used to trigger explosion of a main charge >
# <EntityElement: https://www.wikidata.org/wiki/Q3966 computer hardware         physical components of a computer                 >
# <EntityElement: https://www.wikidata.org/wiki/Q7315950 response                  in liturgy, the second half of one of a set of preces>
# <EntityElement: https://www.wikidata.org/wiki/Q689950 Naan                      Asian flatbread                                   >
# <EntityElement: https://www.wikidata.org/wiki/Q44554 law enforcement           system by which some members of society act in an organized manner to enforce the law>
# <EntityElement: https://www.wikidata.org/wiki/Q814610 emergency service         organizations which ensure public safety and health by addressing different emergencies>
# <EntityElement: https://www.wikidata.org/wiki/Q35127 website                   set of related web pages served from a single web domain>
# <EntityElement: https://www.wikidata.org/wiki/Q11500 area                      quantity that expresses the extent of a two-dimensional surface or shape, or planar lamina, in the p>
# <EntityElement: https://www.wikidata.org/wiki/Q16245820 Assistance                play                                              >
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q7189557 Physical Evidence         1989 film directed by Michael Crichton            >
# <EntityElement: https://www.wikidata.org/wiki/Q35127 website                   set of related web pages served from a single web domain>
# <EntityElement: https://www.wikidata.org/wiki/Q637703 debris                    scattered remains of something destroyed or discarded>
# <EntityElement: https://www.wikidata.org/wiki/Q1249453 improvised explosive device homemade bomb                                     >
# <EntityElement: https://www.wikidata.org/wiki/Q5477678 fragment                  in computer graphics, data necessary to generate a single pixel's worth of a drawing primitive in th>
# <EntityElement: https://www.wikidata.org/wiki/Q3966 computer hardware         physical components of a computer                 >
# <EntityElement: https://www.wikidata.org/wiki/Q214609 base material             substance that can occur in different amounts, all with some similar [mixture of some] characteristi>
# <EntityElement: https://www.wikidata.org/wiki/Q21004260 inquiry                   process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q178651 interview                 structured series of questions and answers        >
# <EntityElement: https://www.wikidata.org/wiki/Q488041 Witness                   1985 American thriller film directed by Peter Weir>
# <EntityElement: https://www.wikidata.org/wiki/Q1851760 victim                    person who suffers as a result of a crime or other event>
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q183252 morphology                biology: the structure and form of organisms      >
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q334401 surveillance              monitoring of behavior, activities, or other changing information>
# <EntityElement: https://www.wikidata.org/wiki/Q11024 communication             act of conveying intended meanings from one entity or group to another through the use of mutually u>
# <EntityElement: https://www.wikidata.org/wiki/Q280658 forward                   Association Football position played near the opponent's goal>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q1347572 evidence                  anything presented in support of an assertion     >
# <EntityElement: https://www.wikidata.org/wiki/Q21004260 inquiry                   process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q280658 forward                   Association Football position played near the opponent's goal>
# <EntityElement: https://www.wikidata.org/wiki/Q908349 motif                     short musical idea, a salient recurring figure, musical fragment or succession of notes that has som>
# <EntityElement: https://www.wikidata.org/wiki/Q2796622 mean                      general term for the several definitions of mean value, the sum divided by the count>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q280658 forward                   Association Football position played near the opponent's goal>
# <EntityElement: https://www.wikidata.org/wiki/Q8222382 legal proceeding          evaluation of evidence to make a decision         >
# <EntityElement: https://www.wikidata.org/wiki/Q1403016 arrest                    the act of apprehending a person and taking them into custody, usually because they have been suspec>
# <EntityElement: https://www.wikidata.org/wiki/Q17310301 bill of indictment        formal accusation that a person has committed a crime>
# <EntityElement: https://www.wikidata.org/wiki/Q8016240 trial                     coming together of parties to a dispute, to present information in a tribunal>
# <EntityElement: https://www.wikidata.org/wiki/Q1763090 sentence                  decree of punishment in law                       >
# <EntityElement: https://www.wikidata.org/wiki/Q10290214 event                     in statistics and probability theory, set of outcomes to which a probability is assigned>
# <EntityElement: https://www.wikidata.org/wiki/Q188473 action film               film genre                                        >
# <EntityElement: https://www.wikidata.org/wiki/Q2992075 conclusion                ending of a musical composition that may take the form of a coda or outro>
# <EntityElement: https://www.wikidata.org/wiki/Q21004260 inquiry                   process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# <EntityElement: https://www.wikidata.org/wiki/Q18602722 Prosecution               1990 Indian Malayalam film directed by Thulasidas >
# <EntityElement: https://www.wikidata.org/wiki/Q703087 provision                 account which records a present liability of an entity>
# <EntityElement: https://www.wikidata.org/wiki/Q1136376 support                   part of the domain of a mathematical function     >
# <EntityElement: https://www.wikidata.org/wiki/Q1851760 victim                    person who suffers as a result of a crime or other event>
# <EntityElement: https://www.wikidata.org/wiki/Q8436 family                    group of people affiliated by consanguinity, affinity, or co-residence>
# <EntityElement: https://www.wikidata.org/wiki/Q21255975 improvement               process of a thing moving from one state to a state considered to be better>
# <EntityElement: https://www.wikidata.org/wiki/Q169489 security                  tradable financial asset                          >
# <EntityElement: https://www.wikidata.org/wiki/Q14536140 exertion                  use of physical or perceived energy by a person   >
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q42889 vehicle                   mobile machine that transports people, animals or cargo>
# <EntityElement: https://www.wikidata.org/wiki/Q198981 target market             group of people toward which an organization has decided to aim its marketing efforts>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q2221906 geographic location       point or an area on the Earth's surface or elsewhere>
# <EntityElement: https://www.wikidata.org/wiki/Q11471 time                      dimension in which events can be ordered from the past through the present into the future>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q4115667 impact                    high force or shock applied over a short time period when two or more bodies collide>
# <EntityElement: https://www.wikidata.org/wiki/Q820655 act                       formal written document that creates law, including acts, executive orders, and by-laws>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q42889 vehicle                   mobile machine that transports people, animals or cargo>
# <EntityElement: https://www.wikidata.org/wiki/Q198981 target market             group of people toward which an organization has decided to aim its marketing efforts>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q4115667 impact                    high force or shock applied over a short time period when two or more bodies collide>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q42889 vehicle                   mobile machine that transports people, animals or cargo>
# <EntityElement: https://www.wikidata.org/wiki/Q198981 target market             group of people toward which an organization has decided to aim its marketing efforts>
# <EntityElement: https://www.wikidata.org/wiki/Q728 weapon                    instrument used to inflict damage or harm to living beings, structures, or systems>
# <EntityElement: https://www.wikidata.org/wiki/Q2796622 mean                      general term for the several definitions of mean value, the sum divided by the count>
# <EntityElement: https://www.wikidata.org/wiki/Q15098235 harm                      moral and legal concept                           >
# <EntityElement: https://www.wikidata.org/wiki/Q188473 action film               film genre                                        >
# <EntityElement: https://www.wikidata.org/wiki/Q44554 law enforcement           system by which some members of society act in an organized manner to enforce the law>
# <EntityElement: https://www.wikidata.org/wiki/Q814610 emergency service         organizations which ensure public safety and health by addressing different emergencies>
# <EntityElement: https://www.wikidata.org/wiki/Q4691992 agency                    refers to the capacity of individuals to act independently and to make their own free choices>
# <EntityElement: https://www.wikidata.org/wiki/Q4049121 scene                     contemporary subculture                           >
# <EntityElement: https://www.wikidata.org/wiki/Q16245820 Assistance                play                                              >
# <EntityElement: https://www.wikidata.org/wiki/Q1851760 victim                    person who suffers as a result of a crime or other event>
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q689950 Naan                      Asian flatbread                                   >
# <EntityElement: https://www.wikidata.org/wiki/Q7189557 Physical Evidence         1989 film directed by Michael Crichton            >
# <EntityElement: https://www.wikidata.org/wiki/Q42889 vehicle                   mobile machine that transports people, animals or cargo>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q5190563 accountability            Responsibility to inform and justify decisions    >
# <EntityElement: https://www.wikidata.org/wiki/Q11028 information               that which informs; the answer to a question of some kind; that from which data and knowledge can be>
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q334401 surveillance              monitoring of behavior, activities, or other changing information>
# <EntityElement: https://www.wikidata.org/wiki/Q488041 Witness                   1985 American thriller film directed by Peter Weir>
# <EntityElement: https://www.wikidata.org/wiki/Q21004260 inquiry                   process that has the aim of augmenting knowledge, resolving doubt, or solving a problem>
# <EntityElement: https://www.wikidata.org/wiki/Q205663 process                   particular execution of a computer program        >
# <EntityElement: https://www.wikidata.org/wiki/Q795052 individual                person or a specific object                       >
# <EntityElement: https://www.wikidata.org/wiki/Q81672 assault                   action intended to harm the goods or the life of others>
# <EntityElement: https://www.wikidata.org/wiki/Q8222382 legal proceeding          evaluation of evidence to make a decision         >
# <EntityElement: https://www.wikidata.org/wiki/Q188473 action film               film genre                                        >

# %%
df_ner_wiki_linking = pd.DataFrame(columns=['Entity','Wiki Desc', 'Wiki Link'])

# %%
index = 0
for index in range(len(all_linked_entities)):
    entity = all_linked_entities[index].get_label()
    wiki_desc = all_linked_entities[index].get_description()
    wiki_link = all_linked_entities[index].get_url()
    new_row = {'Entity':entity,'Wiki Desc':wiki_desc, 'Wiki Link':wiki_link}
    df_ner_wiki_linking = df_ner_wiki_linking.append(new_row, ignore_index=True)

# %%
df_ner_wiki_linking['Wiki Desc'] = df_ner_wiki_linking['Wiki Desc'].str.wrap(30)
dfStyler = df_ner_wiki_linking.style.set_properties(**{'text-align': 'left'})
dfStyler.set_table_styles([dict(selector='th', props=[('text-align', 'left')])])
# Out:
# <style type="text/css">
# #T_be13d th {
#   text-align: left;
# }
# #T_be13d_row0_col0, #T_be13d_row0_col1, #T_be13d_row0_col2, #T_be13d_row1_col0, #T_be13d_row1_col1, #T_be13d_row1_col2, #T_be13d_row2_col0, #T_be13d_row2_col1, #T_be13d_row2_col2, #T_be13d_row3_col0, #T_be13d_row3_col1, #T_be13d_row3_col2, #T_be13d_row4_col0, #T_be13d_row4_col1, #T_be13d_row4_col2, #T_be13d_row5_col0, #T_be13d_row5_col1, #T_be13d_row5_col2, #T_be13d_row6_col0, #T_be13d_row6_col1, #T_be13d_row6_col2, #T_be13d_row7_col0, #T_be13d_row7_col1, #T_be13d_row7_col2, #T_be13d_row8_col0, #T_be13d_row8_col1, #T_be13d_row8_col2, #T_be13d_row9_col0, #T_be13d_row9_col1, #T_be13d_row9_col2, #T_be13d_row10_col0, #T_be13d_row10_col1, #T_be13d_row10_col2, #T_be13d_row11_col0, #T_be13d_row11_col1, #T_be13d_row11_col2, #T_be13d_row12_col0, #T_be13d_row12_col1, #T_be13d_row12_col2, #T_be13d_row13_col0, #T_be13d_row13_col1, #T_be13d_row13_col2, #T_be13d_row14_col0, #T_be13d_row14_col1, #T_be13d_row14_col2, #T_be13d_row15_col0, #T_be13d_row15_col1, #T_be13d_row15_col2, #T_be13d_row16_col0, #T_be13d_row16_col1, #T_be13d_row16_col2, #T_be13d_row17_col0, #T_be13d_row17_col1, #T_be13d_row17_col2, #T_be13d_row18_col0, #T_be13d_row18_col1, #T_be13d_row18_col2, #T_be13d_row19_col0, #T_be13d_row19_col1, #T_be13d_row19_col2, #T_be13d_row20_col0, #T_be13d_row20_col1, #T_be13d_row20_col2, #T_be13d_row21_col0, #T_be13d_row21_col1, #T_be13d_row21_col2, #T_be13d_row22_col0, #T_be13d_row22_col1, #T_be13d_row22_col2, #T_be13d_row23_col0, #T_be13d_row23_col1, #T_be13d_row23_col2, #T_be13d_row24_col0, #T_be13d_row24_col1, #T_be13d_row24_col2, #T_be13d_row25_col0, #T_be13d_row25_col1, #T_be13d_row25_col2, #T_be13d_row26_col0, #T_be13d_row26_col1, #T_be13d_row26_col2, #T_be13d_row27_col0, #T_be13d_row27_col1, #T_be13d_row27_col2, #T_be13d_row28_col0, #T_be13d_row28_col1, #T_be13d_row28_col2, #T_be13d_row29_col0, #T_be13d_row29_col1, #T_be13d_row29_col2, #T_be13d_row30_col0, #T_be13d_row30_col1, #T_be13d_row30_col2, #T_be13d_row31_col0, #T_be13d_row31_col1, #T_be13d_row31_col2, #T_be13d_row32_col0, #T_be13d_row32_col1, #T_be13d_row32_col2, #T_be13d_row33_col0, #T_be13d_row33_col1, #T_be13d_row33_col2, #T_be13d_row34_col0, #T_be13d_row34_col1, #T_be13d_row34_col2, #T_be13d_row35_col0, #T_be13d_row35_col1, #T_be13d_row35_col2, #T_be13d_row36_col0, #T_be13d_row36_col1, #T_be13d_row36_col2, #T_be13d_row37_col0, #T_be13d_row37_col1, #T_be13d_row37_col2, #T_be13d_row38_col0, #T_be13d_row38_col1, #T_be13d_row38_col2, #T_be13d_row39_col0, #T_be13d_row39_col1, #T_be13d_row39_col2, #T_be13d_row40_col0, #T_be13d_row40_col1, #T_be13d_row40_col2, #T_be13d_row41_col0, #T_be13d_row41_col1, #T_be13d_row41_col2, #T_be13d_row42_col0, #T_be13d_row42_col1, #T_be13d_row42_col2, #T_be13d_row43_col0, #T_be13d_row43_col1, #T_be13d_row43_col2, #T_be13d_row44_col0, #T_be13d_row44_col1, #T_be13d_row44_col2, #T_be13d_row45_col0, #T_be13d_row45_col1, #T_be13d_row45_col2, #T_be13d_row46_col0, #T_be13d_row46_col1, #T_be13d_row46_col2, #T_be13d_row47_col0, #T_be13d_row47_col1, #T_be13d_row47_col2, #T_be13d_row48_col0, #T_be13d_row48_col1, #T_be13d_row48_col2, #T_be13d_row49_col0, #T_be13d_row49_col1, #T_be13d_row49_col2, #T_be13d_row50_col0, #T_be13d_row50_col1, #T_be13d_row50_col2, #T_be13d_row51_col0, #T_be13d_row51_col1, #T_be13d_row51_col2, #T_be13d_row52_col0, #T_be13d_row52_col1, #T_be13d_row52_col2, #T_be13d_row53_col0, #T_be13d_row53_col1, #T_be13d_row53_col2, #T_be13d_row54_col0, #T_be13d_row54_col1, #T_be13d_row54_col2, #T_be13d_row55_col0, #T_be13d_row55_col1, #T_be13d_row55_col2, #T_be13d_row56_col0, #T_be13d_row56_col1, #T_be13d_row56_col2, #T_be13d_row57_col0, #T_be13d_row57_col1, #T_be13d_row57_col2, #T_be13d_row58_col0, #T_be13d_row58_col1, #T_be13d_row58_col2, #T_be13d_row59_col0, #T_be13d_row59_col1, #T_be13d_row59_col2, #T_be13d_row60_col0, #T_be13d_row60_col1, #T_be13d_row60_col2, #T_be13d_row61_col0, #T_be13d_row61_col1, #T_be13d_row61_col2, #T_be13d_row62_col0, #T_be13d_row62_col1, #T_be13d_row62_col2, #T_be13d_row63_col0, #T_be13d_row63_col1, #T_be13d_row63_col2 ...

# %%
def make_clickable(link):
    return f'<a target="_blank" href="{link}">{link}</a>'

# %%
df_ner_wiki_linking.style.format({'Wiki Link' : make_clickable})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a6ac5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6ac5_level0_col0" class="col_heading level0 col0" >Entity</th>
#       <th id="T_a6ac5_level0_col1" class="col_heading level0 col1" >Wiki Desc</th>
#       <th id="T_a6ac5_level0_col2" class="col_heading level0 col2" >Wiki Link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6ac5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a6ac5_row0_col0" class="data row0 col0" >group</td>
#       <td id="T_a6ac5_row0_col1" class="data row0 col1" >algebraic set with an
# invertible, associative
# internal operation admitting a
# neutral element</td>
#       <td id="T_a6ac5_row0_col2" class="data row0 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q83478">https://www.wikidata.org/wiki/Q83478</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a6ac5_row1_col0" class="data row1 col0" >individual</td>
#       <td id="T_a6ac5_row1_col1" class="data row1 col1" >person or a specific object</td>
#       <td id="T_a6ac5_row1_col2" class="data row1 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q795052">https://www.wikidata.org/wiki/Q795052</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a6ac5_row2_col0" class="data row2 col0" >military officer</td>
#       <td id="T_a6ac5_row2_col1" class="data row2 col1" >member of an armed force or
# uniformed service who holds a
# position of authority</td>
#       <td id="T_a6ac5_row2_col2" class="data row2 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q189290">https://www.wikidata.org/wiki/Q189290</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a6ac5_row3_col0" class="data row3 col0" >coup d'état</td>
#       <td id="T_a6ac5_row3_col1" class="data row3 col1" >sudden deposition of a
# government; illegal and overt
# seizure of a state by the
# military or other elites
# within the state apparatus</td>
#       <td id="T_a6ac5_row3_col2" class="data row3 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q45382">https://www.wikidata.org/wiki/Q45382</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_a6ac5_row4_col0" class="data row4 col0" >goal</td>
#       <td id="T_a6ac5_row4_col1" class="data row4 col1" >desired result or outcome</td>
#       <td id="T_a6ac5_row4_col2" class="data row4 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q4503831">https://www.wikidata.org/wiki/Q4503831</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_a6ac5_row5_col0" class="data row5 col0" >strategy</td>
#       <td id="T_a6ac5_row5_col1" class="data row5 col1" >high-level plan to achieve
# objectives in uncertain
# conditions</td>
#       <td id="T_a6ac5_row5_col2" class="data row5 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q185451">https://www.wikidata.org/wiki/Q185451</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_a6ac5_row6_col0" class="data row6 col0" >gathering</td>
#       <td id="T_a6ac5_row6_col1" class="data row6 col1" >collecting wild food plants</td>
#       <td id="T_a6ac5_row6_col2" class="data row6 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q2991771">https://www.wikidata.org/wiki/Q2991771</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_a6ac5_row7_col0" class="data row7 col0" >intelligence</td>
#       <td id="T_a6ac5_row7_col1" class="data row7 col1" >mental faculty</td>
#       <td id="T_a6ac5_row7_col2" class="data row7 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q83500">https://www.wikidata.org/wiki/Q83500</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_a6ac5_row8_col0" class="data row8 col0" >coup d'état</td>
#       <td id="T_a6ac5_row8_col1" class="data row8 col1" >sudden deposition of a
# government; illegal and overt
# seizure of a state by the
# military or other elites
# within the state apparatus</td>
#       <td id="T_a6ac5_row8_col2" class="data row8 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q45382">https://www.wikidata.org/wiki/Q45382</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_a6ac5_row9_col0" class="data row9 col0" >government</td>
#       <td id="T_a6ac5_row9_col1" class="data row9 col1" >system or group of people
# governing an organized
# community, often a state</td>
#       <td id="T_a6ac5_row9_col2" class="data row9 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q7188">https://www.wikidata.org/wiki/Q7188</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_a6ac5_row10_col0" class="data row10 col0" >ellipsis</td>
#       <td id="T_a6ac5_row10_col1" class="data row10 col1" >series of dots that indicate
# omission</td>
#       <td id="T_a6ac5_row10_col2" class="data row10 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q32518">https://www.wikidata.org/wiki/Q32518</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_a6ac5_row11_col0" class="data row11 col0" >strength</td>
#       <td id="T_a6ac5_row11_col1" class="data row11 col1" >concept in formal logic</td>
#       <td id="T_a6ac5_row11_col2" class="data row11 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q1989404">https://www.wikidata.org/wiki/Q1989404</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_a6ac5_row12_col0" class="data row12 col0" >asthenia</td>
#       <td id="T_a6ac5_row12_col1" class="data row12 col1" >symptom</td>
#       <td id="T_a6ac5_row12_col2" class="data row12 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q633403">https://www.wikidata.org/wiki/Q633403</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_a6ac5_row13_col0" class="data row13 col0" >coup d'état</td>
#       <td id="T_a6ac5_row13_col1" class="data row13 col1" >sudden deposition of a
# government; illegal and overt
# seizure of a state by the
# military or other elites
# within the state apparatus</td>
#       <td id="T_a6ac5_row13_col2" class="data row13 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q45382">https://www.wikidata.org/wiki/Q45382</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_a6ac5_row14_col0" class="data row14 col0" >construction</td>
#       <td id="T_a6ac5_row14_col1" class="data row14 col1" >process that consists of the
# building or assembling of a
# building or infrastructure</td>
#       <td id="T_a6ac5_row14_col2" class="data row14 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q385378">https://www.wikidata.org/wiki/Q385378</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_a6ac5_row15_col0" class="data row15 col0" >treaty</td>
#       <td id="T_a6ac5_row15_col1" class="data row15 col1" >express agreement under
# international law entered into
# by actors in international law</td>
#       <td id="T_a6ac5_row15_col2" class="data row15 col2" ><a target="_blank" href="https://www.wikidata.org/wiki/Q131569">https://www.wikidata.org/wiki/Q131569</a></td>
#     </tr>
#     <tr>
#       <th id="T_a6ac5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_a6ac5_row16_col0" class="data row16 col0" >coup d'état</td>
#       <td id="T_a6a
